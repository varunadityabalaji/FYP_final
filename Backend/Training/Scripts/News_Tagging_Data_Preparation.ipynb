# %%
import pandas as pd
import tensorflow as tf
import sklearn

# %%
#import all the csvs
apple = pd.read_csv('../Training_Data/Category_Tagging/apple.csv')
amazon = pd.read_csv('../Training_Data/Category_Tagging/amazon.csv')
microsoft = pd.read_csv('../Training_Data/Category_Tagging/microsoft.csv')
facebook = pd.read_csv('../Training_Data/Category_Tagging/facebook.csv')
tesla = pd.read_csv('../Training_Data/Category_Tagging/tesla.csv')
nvidia = pd.read_csv('../Training_Data/Category_Tagging/nvidia.csv')
cisco = pd.read_csv('../Training_Data/Category_Tagging/cisco.csv')
alphabet = pd.read_csv('../Training_Data/Category_Tagging/alphabet.csv')
google = pd.read_csv('../Training_Data/Category_Tagging/google.csv')
broadcom = pd.read_csv('../Training_Data/Category_Tagging/broadcom.csv')

# %%
#dropping the unwanted column
apple = apple.drop(apple.columns[0],axis=1)
apple = apple[apple.Label==1]
amazon = amazon.drop(amazon.columns[0],axis=1)
amazon = amazon[amazon.Label==1]
microsoft  = microsoft.drop(microsoft .columns[0],axis=1)
microsoft = microsoft[microsoft.Label==1]
facebook = facebook.drop(facebook.columns[0],axis=1)
facebook = facebook[facebook.Label==1]
tesla = tesla.drop(tesla.columns[0],axis=1)
tesla = tesla[tesla.Label==1]
nvidia = nvidia.drop(nvidia.columns[0],axis=1)
nvidia = nvidia[nvidia.Label==1]
cisco = cisco.drop(cisco.columns[0],axis=1)
cisco = cisco[cisco.Label==1]
alphabet = alphabet.drop(alphabet.columns[0],axis=1)
alphabet = alphabet[alphabet.Label==1]
google = google.drop(google.columns[0],axis=1)
google = google[google.Label==1]
broadcom = broadcom.drop(broadcom.columns[0],axis=1)
broadcom = broadcom[broadcom.Label==1]

# %%
#apple
is_apple = apple['Label']
is_amazon = [0 for i in range(len(apple))]
is_microsoft = [0 for i in range(len(apple))]
is_facebook = [0 for i in range(len(apple))]
is_tesla = [0 for i in range(len(apple))]
is_nvidia = [0 for i in range(len(apple))]
is_cisco = [0 for i in range(len(apple))]
is_alphabet = [0 for i in range(len(apple))]
is_google = [0 for i in range(len(apple))]
is_broadcom = [0 for i in range(len(apple))]
apple.drop('Label',axis=1)

apple['is_apple'] = is_apple
apple['is_amazon'] = is_amazon
apple['is_microsoft'] = is_microsoft
apple['is_facebook'] = is_facebook
apple['is_tesla'] = is_tesla
apple['is_nvidia'] = is_nvidia
apple['is_cisco'] = is_cisco
apple['is_alphabet'] = is_alphabet
apple['is_google'] = is_google
apple['is_broadcom'] = is_broadcom
apple = apple.drop('Label',axis=1)

# %%
#amazon
is_apple = [0 for i in range(len(amazon))]
is_amazon = amazon['Label']
is_microsoft = [0 for i in range(len(amazon))]
is_facebook = [0 for i in range(len(amazon))]
is_tesla = [0 for i in range(len(amazon))]
is_nvidia = [0 for i in range(len(amazon))]
is_cisco = [0 for i in range(len(amazon))]
is_alphabet = [0 for i in range(len(amazon))]
is_google = [0 for i in range(len(amazon))]
is_broadcom = [0 for i in range(len(amazon))]


amazon['is_apple'] = is_apple
amazon['is_amazon'] = is_amazon
amazon['is_microsoft'] = is_microsoft
amazon['is_facebook'] = is_facebook
amazon['is_tesla'] = is_tesla
amazon['is_nvidia'] = is_nvidia
amazon['is_cisco'] = is_cisco
amazon['is_alphabet'] = is_alphabet
amazon['is_google'] = is_google
amazon['is_broadcom'] = is_broadcom
amazon = amazon.drop('Label',axis=1)

# %%
#microsoft
is_apple = [0 for i in range(len(microsoft))]
is_amazon = [0 for i in range(len(microsoft))]
is_microsoft = microsoft['Label']
is_facebook = [0 for i in range(len(microsoft))]
is_tesla = [0 for i in range(len(microsoft))]
is_nvidia = [0 for i in range(len(microsoft))]
is_cisco = [0 for i in range(len(microsoft))]
is_alphabet = [0 for i in range(len(microsoft))]
is_google = [0 for i in range(len(microsoft))]
is_broadcom = [0 for i in range(len(microsoft))]


microsoft['is_apple'] = is_apple
microsoft['is_amazon'] = is_amazon
microsoft['is_microsoft'] = is_microsoft
microsoft['is_facebook'] = is_facebook
microsoft['is_tesla'] = is_tesla
microsoft['is_nvidia'] = is_nvidia
microsoft['is_cisco'] = is_cisco
microsoft['is_alphabet'] = is_alphabet
microsoft['is_google'] = is_google
microsoft['is_broadcom'] = is_broadcom
microsoft = microsoft.drop('Label',axis=1)

# %%
#facebook
is_apple = [0 for i in range(len(facebook))]
is_amazon = [0 for i in range(len(facebook))]
is_microsoft = [0 for i in range(len(facebook))]
is_facebook = facebook['Label']
is_tesla = [0 for i in range(len(facebook))]
is_nvidia = [0 for i in range(len(facebook))]
is_cisco = [0 for i in range(len(facebook))]
is_alphabet = [0 for i in range(len(facebook))]
is_google = [0 for i in range(len(facebook))]
is_broadcom = [0 for i in range(len(facebook))]


facebook['is_apple'] = is_apple
facebook['is_amazon'] = is_amazon
facebook['is_microsoft'] = is_microsoft
facebook['is_facebook'] = is_facebook
facebook['is_tesla'] = is_tesla
facebook['is_nvidia'] = is_nvidia
facebook['is_cisco'] = is_cisco
facebook['is_alphabet'] = is_alphabet
facebook['is_google'] = is_google
facebook['is_broadcom'] = is_broadcom
facebook = facebook.drop('Label',axis=1)

# %%
#tesla
is_apple = [0 for i in range(len(tesla))]
is_amazon = [0 for i in range(len(tesla))]
is_microsoft = [0 for i in range(len(tesla))]
is_facebook = [0 for i in range(len(tesla))]
is_tesla = tesla['Label']
is_nvidia = [0 for i in range(len(tesla))]
is_cisco = [0 for i in range(len(tesla))]
is_alphabet = [0 for i in range(len(tesla))]
is_google = [0 for i in range(len(tesla))]
is_broadcom = [0 for i in range(len(tesla))]


tesla['is_apple'] = is_apple
tesla['is_amazon'] = is_amazon
tesla['is_microsoft'] = is_microsoft
tesla['is_facebook'] = is_facebook
tesla['is_tesla'] = is_tesla
tesla['is_nvidia'] = is_nvidia
tesla['is_cisco'] = is_cisco
tesla['is_alphabet'] = is_alphabet
tesla['is_google'] = is_google
tesla['is_broadcom'] = is_broadcom
tesla = tesla.drop('Label',axis=1)

# %%
#nvidia
is_apple = [0 for i in range(len(nvidia))]
is_amazon = [0 for i in range(len(nvidia))]
is_microsoft = [0 for i in range(len(nvidia))]
is_facebook = [0 for i in range(len(nvidia))]
is_tesla = [0 for i in range(len(nvidia))]
is_nvidia = nvidia['Label']
is_cisco = [0 for i in range(len(nvidia))]
is_alphabet = [0 for i in range(len(nvidia))]
is_google = [0 for i in range(len(nvidia))]
is_broadcom = [0 for i in range(len(nvidia))]


nvidia['is_apple'] = is_apple
nvidia['is_amazon'] = is_amazon
nvidia['is_microsoft'] = is_microsoft
nvidia['is_facebook'] = is_facebook
nvidia['is_tesla'] = is_tesla
nvidia['is_nvidia'] = is_nvidia
nvidia['is_cisco'] = is_cisco
nvidia['is_alphabet'] = is_alphabet
nvidia['is_google'] = is_google
nvidia['is_broadcom'] = is_broadcom
nvidia = nvidia.drop('Label',axis=1)

# %%
#cisco
is_apple = [0 for i in range(len(cisco))]
is_amazon = [0 for i in range(len(cisco))]
is_microsoft = [0 for i in range(len(cisco))]
is_facebook = [0 for i in range(len(cisco))]
is_tesla = [0 for i in range(len(cisco))]
is_nvidia = [0 for i in range(len(cisco))]
is_cisco = cisco['Label']
is_alphabet = [0 for i in range(len(cisco))]
is_google = [0 for i in range(len(cisco))]
is_broadcom = [0 for i in range(len(cisco))]


cisco['is_apple'] = is_apple
cisco['is_amazon'] = is_amazon
cisco['is_microsoft'] = is_microsoft
cisco['is_facebook'] = is_facebook
cisco['is_tesla'] = is_tesla
cisco['is_nvidia'] = is_nvidia
cisco['is_cisco'] = is_cisco
cisco['is_alphabet'] = is_alphabet
cisco['is_google'] = is_google
cisco['is_broadcom'] = is_broadcom
cisco = cisco.drop('Label',axis=1)

# %%
#alphabet
is_apple = [0 for i in range(len(alphabet))]
is_amazon = [0 for i in range(len(alphabet))]
is_microsoft = [0 for i in range(len(alphabet))]
is_facebook = [0 for i in range(len(alphabet))]
is_tesla = [0 for i in range(len(alphabet))]
is_nvidia = [0 for i in range(len(alphabet))]
is_cisco = [0 for i in range(len(alphabet))]
is_alphabet = alphabet['Label']
is_google = [0 for i in range(len(alphabet))]
is_broadcom = [0 for i in range(len(alphabet))]


alphabet['is_apple'] = is_apple
alphabet['is_amazon'] = is_amazon
alphabet['is_microsoft'] = is_microsoft
alphabet['is_facebook'] = is_facebook
alphabet['is_tesla'] = is_tesla
alphabet['is_nvidia'] = is_nvidia
alphabet['is_cisco'] = is_cisco
alphabet['is_alphabet'] = is_alphabet
alphabet['is_google'] = is_google
alphabet['is_broadcom'] = is_broadcom
alphabet = alphabet.drop('Label',axis=1)

# %%
#google
is_apple = [0 for i in range(len(google))]
is_amazon = [0 for i in range(len(google))]
is_microsoft = [0 for i in range(len(google))]
is_facebook = [0 for i in range(len(google))]
is_tesla = [0 for i in range(len(google))]
is_nvidia = [0 for i in range(len(google))]
is_cisco = [0 for i in range(len(google))]
is_alphabet = [0 for i in range(len(google))]
is_google = google['Label']
is_broadcom = [0 for i in range(len(google))]


google['is_apple'] = is_apple
google['is_amazon'] = is_amazon
google['is_microsoft'] = is_microsoft
google['is_facebook'] = is_facebook
google['is_tesla'] = is_tesla
google['is_nvidia'] = is_nvidia
google['is_cisco'] = is_cisco
google['is_alphabet'] = is_alphabet
google['is_google'] = is_google
google['is_broadcom'] = is_broadcom
google = google.drop('Label',axis=1)

# %%
#broadcom
is_apple = [0 for i in range(len(broadcom))]
is_amazon = [0 for i in range(len(broadcom))]
is_microsoft = [0 for i in range(len(broadcom))]
is_facebook = [0 for i in range(len(broadcom))]
is_tesla = [0 for i in range(len(broadcom))]
is_nvidia = [0 for i in range(len(broadcom))]
is_cisco = [0 for i in range(len(broadcom))]
is_alphabet = [0 for i in range(len(broadcom))]
is_google = [0 for i in range(len(broadcom))]
is_broadcom = broadcom['Label']


broadcom['is_apple'] = is_apple
broadcom['is_amazon'] = is_amazon
broadcom['is_microsoft'] = is_microsoft
broadcom['is_facebook'] = is_facebook
broadcom['is_tesla'] = is_tesla
broadcom['is_nvidia'] = is_nvidia
broadcom['is_cisco'] = is_cisco
broadcom['is_alphabet'] = is_alphabet
broadcom['is_google'] = is_google
broadcom['is_broadcom'] = is_broadcom
broadcom = broadcom.drop('Label',axis=1)

# %%
#combining
df_final = apple.append(amazon).append(microsoft).append(facebook).append(tesla).append(nvidia).append(cisco).append(alphabet).append(google).append(broadcom)
# Out:
# /var/folders/8y/6j0y5pg92ng64xbpn5hywscc0000gn/T/ipykernel_966/2163418072.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_final = apple.append(amazon).append(microsoft).append(facebook).append(tesla).append(nvidia).append(cisco).append(alphabet).append(google).append(broadcom)
# /var/folders/8y/6j0y5pg92ng64xbpn5hywscc0000gn/T/ipykernel_966/2163418072.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_final = apple.append(amazon).append(microsoft).append(facebook).append(tesla).append(nvidia).append(cisco).append(alphabet).append(google).append(broadcom)
# /var/folders/8y/6j0y5pg92ng64xbpn5hywscc0000gn/T/ipykernel_966/2163418072.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_final = df_final.sample(frac=1)

# %%
df_final.to_csv('../Training_Data/Category_Tagging/final_data.csv')

# %%
df_final
# Out:
#                                                    News  is_apple  is_amazon  \
# 3320  Google chief Pichai takes helm of parent Alpha...         0          0
# 49    Apple supplier OFilm tells investors it lost '...         1          0
# 271   U.S. launches investigation into Tesla Model S...         0          0
# 1615  EXCLUSIVE-France sues Apple over developer con...         1          0
# 3138  Flat European shares helped by positive earnin...         0          0
# ...                                                 ...       ...        ...
# 137   US STOCKS-Wall St flat after Apple starts divi...         0          0
# 997   UPDATE 3-Broadcom eyes more smartphone chip sales         0          0
# 1361              Adyen adds Amazon Pay to its offering         0          1
# 898   UPDATE 1-Flash storage provider Violin Memory ...         0          0
# 2789  UK watchdog opens formal probe into Amazon, Go...         0          0
#
# ...
